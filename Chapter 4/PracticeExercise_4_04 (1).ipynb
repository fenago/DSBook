# %% [markdown]
# ## **Practice Exercise 4.04**:
# ###  Tuning min_samples_leaf

# %%
#@title Default title text
import pandas as pd
import numpy as np

# %%
#@title Loading data
animals_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%204/zoo2.csv')

animals_data.head()

# %% [markdown]
# ### Remove the Type column using .drop() and then extract the Type targetvariable

# %%
# Type your code here:

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Instantiate RandomForestClassifier with random_state=42 and n_estimators=30, max_depth=2,  min_samples_leaf=7, and then fit the model with the training set:

# %% [markdown]
# ### Make predictions on the training and testing sets with .predict()

# %% [markdown]
# ### Print the accuracy scores: train_acc and test_acc:

# %% [markdown]
# ### Instantiating another RandomForestClassifier  with random_state=42, n_estimators=30, and max_depth=2, and  min_samples_leaf=7

# %% [markdown]
# ### Make predictions on the training and testing sets with .predict()

# %% [markdown]
# ### Calculating the accuracy score for the training and testing sets a

# %% [markdown]
# ###  Printing the accuracy scores: train_acc and test_acc:

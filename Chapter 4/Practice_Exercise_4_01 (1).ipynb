# %% [markdown]
# ## **Practice Exercise 4.01**:
# ###  Tuning max_features

# %%
#@title Importing modules
import pandas as pd
import numpy as np

# %%
#@title Loading Data
animals_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%204/zoo2.csv')

animals_data.head()

# %% [markdown]
# ### Remove the Type column using .drop() and then extract the Type targetvariable

# %%
from sklearn.model_selection import train_test_split

# %%
# ---- type your code here ---#

# %% [markdown]
# ### Instantiate RandomForestClassifier with random_state=42 and n_estimators=10, and then fit the model with the training set:

# %% [markdown]
# ### **Practice Exercise 4.02**:
# ### Tuning n_estimators to Reduce Overfitting

# %%
#@title Importing modules
import pandas as pd
import numpy as np

# %%
#@title Loading data
animals_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%204/zoo2.csv')

animals_data.head()

# %% [markdown]
# ### Remove the Type column using .drop() and then extract the Type targetvariable

# %%
# ---- type your code here ---#

# %% [markdown]
# ### Instantiate RandomForestClassifier with random_state=42 and n_estimators=1, and then fit the model with the training set:

# %% [markdown]
# ### Make predictions on the training and testing sets with .predict()

# %%
from sklearn.metrics import accuracy_score

train_acc = accuracy_score(y_train, train_preds)
test_acc = accuracy_score(y_test, test_preds)

# %% [markdown]
# ### Print the accuracy scores: train_acc and test_acc:

# %% [markdown]
# ### Instantiating another RandomForestClassifier with random_state=42 and n_estimators=30

# %%
# Out:
# RandomForestClassifier(n_estimators=30, random_state=42)

# %% [markdown]
# ### Make predictions on the training and testing sets with .predict()

# %% [markdown]
# ### Calculating the accuracy score for the training and testing sets a

# %% [markdown]
# ###  Printing the accuracy scores: train_acc and test_acc:

# %%
# Out:
# 1.0
# 0.7209302325581395

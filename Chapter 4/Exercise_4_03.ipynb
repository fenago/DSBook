# %% [markdown]
# ## **Exercise 4.03**:
# ###  Tuning max_depth to Reduce Overfittin

# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading data

# %%
glass_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%204/glass.csv')

glass_data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %% [markdown]
# ### Remove the Type column using .drop() and then extract the Type targetvariable

# %%
# Type your code here:



# ---Solution ---#
#target = glass_data.pop('Type')
#glass_data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %%
from sklearn.model_selection import train_test_split

# %%
# ---- type your code here ---#



# --- Solution --- #
#X_train, X_test, y_train, y_test = train_test_split\
 #                                 (glass_data, target, test_size=0.4, \
 #                                 random_state=188)

# %% [markdown]
# ### Instantiate RandomForestClassifier with random_state=42 and n_estimators=30, and max_depth=5, and then fit the model with the training set:

# %%
from sklearn.ensemble import RandomForestClassifier
# ---- type your code here ---#



# --- Solution --- #
#f_model = RandomForestClassifier(random_state=42, \
#                                  n_estimators=30, \
#                                    max_depth=5)

#f_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=30, random_state=42)

# %% [markdown]
# ### Make predictions on the training and testing sets with .predict()

# %%
# ---- type your code here ---#



# --- Solution --- #
#train_preds = f_model.predict(X_train)
Etest_preds = f_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

train_acc = accuracy_score(y_train, train_preds)
test_acc = accuracy_score(y_test, test_preds)

# %% [markdown]
# ### Print the accuracy scores: train_acc and test_acc:

# %%
print(train_acc)
print(test_acc)
# Out:
# 0.8671875
# 0.6744186046511628

# %% [markdown]
# ### Instantiating another RandomForestClassifier  with random_state=42, n_estimators=30, and max_depth=2

# %%
f_model2 = RandomForestClassifier(random_state=42, \
                                   n_estimators=30,\
                                    max_depth=2)
f_model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=30, random_state=42)

# %% [markdown]
# ### Make predictions on the training and testing sets with .predict()

# %%
train_preds2 = f_model2.predict(X_train)
test_preds2 = f_model2.predict(X_test)

# %% [markdown]
# ### Calculating the accuracy score for the training and testing sets a

# %%
train_acc2 = accuracy_score(y_train, train_preds2)
test_acc2 = accuracy_score(y_test, test_preds2)

# %% [markdown]
# ###  Printing the accuracy scores: train_acc and test_acc:

# %%
print(train_acc2)
print(test_acc2)
# Out:
# 0.6953125
# 0.5930232558139535

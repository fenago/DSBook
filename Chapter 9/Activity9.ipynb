# %% [markdown]
# ## **Activity 9**

# %%
#@title Import Modules
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import altair as alt
from sklearn.inspection import plot_partial_dependence
from mlxtend.evaluate import feature_importance_permutation

# %%
#@title Load data

df = pd.read_csv('https://raw.githubusercontent.com/PacktWorkshops/The-Data-Science-Workshop/master/Chapter09/Dataset/KDDCup99.csv')
df.head()

# %%
#@title Extracting label and saving in "y"
y = df.pop('label')

# %% [markdown]
# ### Split the dataset into training and test sets using train_test_split() from sklearn.model_selection.

# %% [markdown]
# ### Create a function that will instantiate and fit RandomForestClassifier using .fit() from sklearn.ensemble

# %% [markdown]
# ### Create a function that will predict the outcome for the training and testing sets  using .predict().

# %% [markdown]
# ### Create a function that will print the accuracy score for the training and testing  sets using accuracy_score() from sklearn.metrics.

# %% [markdown]
# ### Compute the feature importance via permutation with feature_importance_permutation() and display it on a bar chart using altair

# %% [markdown]
# ### Plot the partial dependence plot using plot_partial_dependence on the  src_bytes variable.

# %% [markdown]
# ### Install LIME

# %% [markdown]
# ### Perform a LIME analysis on row 99893 with explain_instance()

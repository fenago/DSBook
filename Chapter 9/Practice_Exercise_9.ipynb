# %% [markdown]
# ### **Practice Exercise 9**

# %%
#@title Import Modules
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import plot_partial_dependence
import altair as alt

# %%
#@title Loading Data
df = pd.read_csv('https://raw.githubusercontent.com/PacktWorkshops/The-Data-Science-Workshop/master/Chapter09/Dataset/phpYYZ4Qc.csv')

# %% [markdown]
# ### Extract "rej" from data

# %% [markdown]
# ### Split the DataFrame into training and testing sets using train_test_split() with test_size=0.3 and random_state = 1:

# %% [markdown]
# ### Instantiate RandomForestRegressor with random_state=1, n_estimators=50, max_depth=6, and min_samples_leaf=60:

# %% [markdown]
# ### Train the model on the training set using .fit():

# %% [markdown]
# ### Plot the partial dependence plot using plot_partial_dependence()

# %% [markdown]
# ### Plot the partial dependence plot using plot_partial_dependence() from sklearn with the Random Forest model,

# %% [markdown]
# ## **Practice Exercise 01 - Skill Check:** Loading and Preparing the Data for Analysis - A housing Dataset
#
# ### Practice the question to build a correlation matrix for another "Housing" Dataset in the similar way as depicted in previous Exercise

# %%
# Importing necessary modules
# !pip install pandas
# !pip install sklearn
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#import modules here:

# %% [markdown]
# ### Loading Dataset:

# %%
Housing_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%202/Housing.csv')
# Write code to display first five entries:

# %% [markdown]
# ### Check for missing values (null values) in the DataFrame

# %% [markdown]
# ### Checking for duplicate data and removing it

# %%
#Write code to list the column names:
# Out:
# ['price',
#  'area',
#  'bedrooms',
#  'bathrooms',
#  'stories',
#  'mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'parking',
#  'prefarea',
#  'furnishingstatus']

# %% [markdown]
# ### Inspect the data types of the columns using ".info()":

# %% [markdown]
# ### Calculate basic statistics for the numeric columns in the DataFrame:

# %% [markdown]
# ### Divide the DataFrame into training and test sets
# ### Treat "Price" as a dependent Variable

# %% [markdown]
# ### Calculate and plot a correlation matrix for the train_data set

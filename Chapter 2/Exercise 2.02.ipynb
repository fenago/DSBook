# %% [markdown]
# Exercise 2.02 - Guided Exercise:
# Graphical Investigation of Linear Relationships Using Python

# %%
# %matplotlib inline
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg
import pandas as pd
import numpy as np
import patsy
from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split
plt.style.use('seaborn')

# %% [markdown]
# LOADING MIAMI_HOUSING DATASET AND DISPLAYING FIRST 5 ENTRIES

# %%
miami_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/miami-housing.csv')
miami_data.head()

# %% [markdown]
# Check for missing values (null values) in the DataFrame

# %%
raw_data = miami_data.dropna()
raw_data = raw_data.drop_duplicates()

#----Write your code here----#



#-------Solution:---------#
#renamedMiamiData = raw_data.rename\
#(columns = {\
#'LATITUDE':'LATITUDE',\
#'LONGITUDE ':'LONGITUDE',\
#'PARCELNO ':'ParcelNumber',\
#'SALE_PRC':'SalePrice',\
#'LND_SQFOOT':'LandLength'})
#renamedMiamiData.head()

# %% [markdown]
# Setting up the test and train data:

# %%
X = renamedMiamiData.drop('SalePrice', axis = 1)
y = renamedMiamiData[['SalePrice']]
seed = 10
test_data_size = 0.3


#----Write your code here----#



#-------Solution:---------#
#X_train, X_test, \
#y_train, y_test = train_test_split(X, y, \
#test_size = test_data_size, \
#random_state = seed)
#train_data = pd.concat([X_train, y_train], axis = 1)
#test_data = pd.concat([X_test, y_test], axis = 1)

# %% [markdown]
# Using the subplots function in matplotlib to define a canvas and a graph object - ax in Python. You can set the size of the graph by setting the figsize (width = 10, height = 6) argument of the function.Use the seaborn function regplot to create the scatter plot

# %%
#----Write your code here----#



#-------Solution:---------#
#fig, ax = plt.subplots(figsize=(10, 6))
#sns.regplot(x='LandLength', y='SalePrice', ci=None, \
#            data=train_data, ax=ax, color='k', \
#           scatter_kws={"s": 20,"color": "royalblue", \
#           "alpha":1})
#ax.set_ylabel('Sale Price',fontsize=15, fontname='DejaVu Sans')
#ax.set_xlabel("Land Length ", fontsize=15, \
#              fontname='DejaVu Sans')
#ax.set_xlim(left=None, right=None)
#ax.set_ylim(bottom=None, top=None)
#ax.tick_params(axis='both', which='major', labelsize=12)
#fig.tight_layout()

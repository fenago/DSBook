# %% [markdown]
# ## **Practice Exercise - 04  - Skill Check**
#
# ### Fitting a Simple Linear Regression Model Using the Statsmodels formula API
# Practice this exercise according to the instructions given in description:

# %% [markdown]
# ### Import necessary Modules:

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Loading Data

# %%
Housing_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%202/Housing.csv')

# Write code to display first five entries:

# %%
#Inspecting the data types of the columns

# %% [markdown]
# ### Define a linear regression model and store it in a variable:

# %% [markdown]
# ### Call the .fit() method of the model instance and assign the results of the method to a variable,

# %% [markdown]
# ### Finally, Print the summary stored in Model - Regression analysis results
# Your output should  be consistent with the given output

# %% [markdown]
# **Exercise 2.05 - Guided Exercise:**
#
# Fitting a Multiple Linear Regression Model using the StatsModels Formula API:

# %%
import statsmodels.formula.api as smf
import pandas as pd
from sklearn.model_selection import train_test_split

# %matplotlib inline
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg
import numpy as np
import patsy
from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split
plt.style.use('seaborn')

# %% [markdown]
# LOADING MIAMI_HOUSING DATASET AND DISPLAYING FIRST 5 ENTRIES

# %%
miami_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/DSBook/main/miami-housing.csv')
miami_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da8209302e96> in <module>()
# ----> 1 miami_data = pd.read_csv('https://raw.githubusercontent.com/fenago/datasets/main/BankNote_Authentication.csv')
#       2 miami_data.head()
#
# NameError: name 'pd' is not defined

# %%
raw_data = miami_data.dropna()

# %%
raw_data = raw_data.drop_duplicates()

# %% [markdown]
# Listing the column names of the DataFrame

# %%
list(raw_data.columns)

# %% [markdown]
# Renaming the DataFrame columns from 1 to 5, others are kept same

# %%
renamedMiamiData = raw_data.rename\
(columns = {\
'LATITUDE':'LATITUDE',\
' LONGITUDE ':'lONGITUDE',\
'PARCELNO ':'Parcel Number',\
'SALE_PRC':'SalePrice',\
'LND_SQFOOT':'LandLength'})
renamedMiamiData.head()

# %%
renamedMiamiData.describe(include=[np.number]).T

# %% [markdown]
# Divide the DataFrame into training and test sets

# %%
X = renamedMiamiData.drop('SalePrice', axis = 1)
y = renamedMiamiData[['SalePrice']]
seed = 10
test_data_size = 0.3
X_train, X_test, \
y_train, y_test = train_test_split(X, y, \
test_size = test_data_size, \
random_state = seed)
train_data = pd.concat([X_train, y_train], axis = 1)
test_data = pd.concat([X_test, y_test], axis = 1)

# %% [markdown]
# Using the + operator of Patsy formula language to define a linear regression model for SalePrice (dependent Variable) on PARCELNO,WATER_DIST,LandLength,RAIL_DIST (independent Variables).

# %%
#----Write your code here----#



#-------Solution:---------#
#multiLinearModel = smf.ols\
#                 (formula = 'SalePrice ~ PARCELNO \
#+ WATER_DIST \
#+ LandLength \
#+ RAIL_DIST', \
#data=train_data)

# %% [markdown]
# Fit method of the model instance:

# %%
FinalmultiLinearModel = multiLinearModel.fit()

# %% [markdown]
# Printing the summary of multi Regression model

# %%
print(FinalmultiLinearModel.summary())

# %% [markdown]
# ## **Practice Exercise 03 - Skill Check**
# ### Solve the given exercise to assess yourself!
# ### Follow the steps mentioned below to complete the exercise

# %% [markdown]
# ### Import modules

# %% [markdown]
# ### Import dataset

# %%
# Read CSV train data file into DataFrame
train_df = pd.read_csv("https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%203/gender_submission.csv")

# preview train data

# %% [markdown]
# ### Print the shape of dataset

# %% [markdown]
# ### check missing values in train data

# %% [markdown]
# ### Percent of  "Survived"

# %% [markdown]
# ### Make Density plot for survived:

# %% [markdown]
# ## **Exercise 3.04:**
# ### Feature Engineering – Creating New Features from Existing Ones

# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading Data

# %%
notes_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/datasets/main/BankNote_Authentication.csv')
#-------Type code here to display first five entries from daatset ------#


#------Solution------#
#notes_data.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %% [markdown]
# ### Applying data Normalization:

# %%
# Normalizing data

# Type your code here:


# --- Solution ---#
#from sklearn import preprocessing
#x = notes_data[['variance']].values.astype(float)

# %% [markdown]
# ### Applying Preprocessing:

# %%
minmaxScaler = preprocessing.MinMaxScaler()

# %%
notes_data['VarianceTransformed'] = minmaxScaler.fit_transform(x)

# %% [markdown]
# ###  Print the head of the data using the .head() function:

# %%
notes_data.head()
# Out:
#    variance  skewness  curtosis  entropy  class  VarianceTransformed
# 0   3.62160    8.6661   -2.8073 -0.44699      0             0.769004
# 1   4.54590    8.1674   -2.4586 -1.46210      0             0.835659
# 2   3.86600   -2.6383    1.9242  0.10645      0             0.786629
# 3   3.45660    9.5228   -4.0112 -3.59440      0             0.757105
# 4   0.32924   -4.4552    4.5718 -0.98880      0             0.531578

# %% [markdown]
# ### Eliminating 0 values

# %%
# Adding a small numerical constant to eliminate 0 values
notes_data['VarianceTransformed'] = notes_data['VarianceTransformed'] + 0.00001

# %%
# Let us transform values for skewness data
notes_data['SkewnessTransformed'] = 1

notes_data.loc[notes_data['SkewnessTransformed'] == 'no', 'SkewnessTransformed'] = 5
notes_data.head()
# Out:
#    variance  skewness  curtosis  entropy  class  VarianceTransformed  \
# 0   3.62160    8.6661   -2.8073 -0.44699      0             0.769014
# 1   4.54590    8.1674   -2.4586 -1.46210      0             0.835669
# 2   3.86600   -2.6383    1.9242  0.10645      0             0.786639
# 3   3.45660    9.5228   -4.0112 -3.59440      0             0.757115
# 4   0.32924   -4.4552    4.5718 -0.98880      0             0.531588
#
#    SkewnessTransformed
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
# Let us transform values for curtosis data

# Type your code here:


# ---Solution ----#
#notes_data['CurtosisTransformed'] = 3

# %%
print(notes_data.head())
# Out:
#    variance  skewness  curtosis  entropy  class  VarianceTransformed  \
# 0   3.62160    8.6661   -2.8073 -0.44699      0             0.769014
# 1   4.54590    8.1674   -2.4586 -1.46210      0             0.835669
# 2   3.86600   -2.6383    1.9242  0.10645      0             0.786639
# 3   3.45660    9.5228   -4.0112 -3.59440      0             0.757115
# 4   0.32924   -4.4552    4.5718 -0.98880      0             0.531588
#
#    SkewnessTransformed  CurtosisTransformed
# 0                    1                    3
# 1                    1                    3
# 2                    1                    3
# 3                    1                    3
# 4                    1                    3

# %%
""" 
Let us now create the new variable which is a product of all 
these
"""
notes_data['Index'] = notes_data['VarianceTransformed'] \
                         * notes_data['SkewnessTransformed'] 
notes_data.head()
# Out:
#    variance  skewness  curtosis  entropy  class  VarianceTransformed  \
# 0   3.62160    8.6661   -2.8073 -0.44699      0             0.769014
# 1   4.54590    8.1674   -2.4586 -1.46210      0             0.835669
# 2   3.86600   -2.6383    1.9242  0.10645      0             0.786639
# 3   3.45660    9.5228   -4.0112 -3.59440      0             0.757115
# 4   0.32924   -4.4552    4.5718 -0.98880      0             0.531588
#
#    SkewnessTransformed  CurtosisTransformed     Index
# 0                    1                    3  0.769014
# 1                    1                    3  0.835669
# 2                    1                    3  0.786639
# 3                    1                    3  0.757115
# 4                    1                    3  0.531588

# %% [markdown]
# ### Finding the quantile:

# %%
# Finding the quantile
np.quantile(notes_data['Index'],[0.25,0.5,0.75])
# Out:
# array([0.37998678, 0.54362681, 0.71131354])

# %%
notes_data['Class'] = 'Quant1'
notes_data.loc[(notes_data['Index'] > 0.379) \
              & (notes_data['Index'] < 0.543), \
              'Class'] = 'Quant2'
notes_data.loc[(notes_data['Index'] > 0.543) \
              & (notes_data['Index'] < 0.711), \
              'Class'] = 'Quant3'
notes_data.loc[notes_data['Index'] > 0.711, \
             'Class'] = 'Quant4'
notes_data.head()
notes_data.Class[notes_data['Index'] > 0.711] = 'Quant4'
notes_data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    variance  skewness  curtosis  entropy  class  VarianceTransformed  \
# 0   3.62160    8.6661   -2.8073 -0.44699      0             0.769014
# 1   4.54590    8.1674   -2.4586 -1.46210      0             0.835669
# 2   3.86600   -2.6383    1.9242  0.10645      0             0.786639
# 3   3.45660    9.5228   -4.0112 -3.59440      0             0.757115
# 4   0.32924   -4.4552    4.5718 -0.98880      0             0.531588
#
#    SkewnessTransformed  CurtosisTransformed     Index   Class
# 0                    1                    3  0.769014  Quant4
# 1                    1                    3  0.835669  Quant4
# 2                    1                    3  0.786639  Quant4
# 3                    1                    3  0.757115  Quant4
# 4                    1                    3  0.531588  Quant2

# %% [markdown]
# ### Calculating total

# %%
# Calculating total of each above  class
ClassToT = notes_data.groupby('Class')['class']\
                   .agg(ClassToT='count').reset_index()
# Calculating the category wise counts
Category = notes_data.groupby(['Class', 'class'])['class']\
                    .agg(Cat='count').reset_index()

# %% [markdown]
# ### Merging both the data frames

# %%
# Type your Code here for Merging:



# ---Solution ---#
#Comb = pd.merge(Category, ClassToT, on = ['Class'])
#Comb['Category_final'] = (Comb.Cat \
#                        / Comb.ClassToT)*100
#Comb
# Out:
#     Class  class  Cat  ClassToT  Category_final
# 0  Quant1      0   33       341        9.677419
# 1  Quant1      1  308       341       90.322581
# 2  Quant2      0  111       343       32.361516
# 3  Quant2      1  232       343       67.638484
# 4  Quant3      0  274       344       79.651163
# 5  Quant3      1   70       344       20.348837
# 6  Quant4      0  344       344      100.000000

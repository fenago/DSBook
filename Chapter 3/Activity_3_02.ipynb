# %% [markdown]
# ## **Activity 3.02**
# ### Logistic Regression Model with Feature Engineered Variables

# %% [markdown]
# ### Importing necessary modules

# %%
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Loading data

# %%
notes_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/datasets/main/BankNote_Authentication.csv')
#-------Type code here to display first five entries from daatset ------#


#------Solution------#
#notes_data.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %% [markdown]
# ### Selecting the numerical variables

# %%
 #All of the variables are numerical:
# Just type your code here to obtain them:



# --- Solytion ---#
#notes_Num = notes_data[['variance','skewness',\
 #                   'curtosis','entropy']]

# Printing the shape:
notes_Num.shape
# Out:
# (1372, 4)

# %% [markdown]
# ### Create dummy variables for categorical variables. Since all variables were numeric, so convert them here:

# %%
'''
Converting all the categorical variables to dummy variables
'''

dm_var = pd.get_dummies\
          (notes_data[['variance','skewness',\
                     'curtosis','entropy']])
dm_var.shape
# Out:
# (1372, 4)

# %% [markdown]
# ### Transform some of the numerical variables by normalizing them using the MinMaxScaler() function.

# %%
minmaxScaler = preprocessing.MinMaxScaler()
minmaxScaler
# Out:
# MinMaxScaler()

# %%
# Normalizing data

# Type your code here:


# --- Solution ---#
#x = notes_data[['variance']].values.astype(float)

# %% [markdown]
# ### Concatenate the numerical variables and categorical variables

# %%
# Type your code here:






# ---Solution ---#
# Preparing the X variables
#X = pd.concat([dm_var, notes_Num], axis=1)
#print(X.shape)
# Preparing the Y variable
#Y = notes_data['class']
#print(Y.shape)
X.head()
# Out:
# (1372, 8)
# (1372,)
#    variance  skewness  curtosis  entropy  variance  skewness  curtosis  \
# 0   3.62160    8.6661   -2.8073 -0.44699   3.62160    8.6661   -2.8073
# 1   4.54590    8.1674   -2.4586 -1.46210   4.54590    8.1674   -2.4586
# 2   3.86600   -2.6383    1.9242  0.10645   3.86600   -2.6383    1.9242
# 3   3.45660    9.5228   -4.0112 -3.59440   3.45660    9.5228   -4.0112
# 4   0.32924   -4.4552    4.5718 -0.98880   0.32924   -4.4552    4.5718
#
#    entropy
# 0 -0.44699
# 1 -1.46210
# 2  0.10645
# 3 -3.59440
# 4 -0.98880

# %% [markdown]
# ### Splitting the dataset using the train_test_split() function

# %%
#  Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split\
                                   (X, Y, test_size=0.3, \
                                    random_state=123)

# %% [markdown]
# ###  fitting a new model using the LogisticRegression() model on the new features.

# %%
notes_Model = LogisticRegression()
notes_Model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = notes_Model.predict(X_test)
print('Accuracy of Logistic regression model' \
      'prediction on test set is: {:.2f}'\
      .format(notes_Model.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression modelprediction on test set is: 0.99

# %%
# For generating a classification report, type your code here:



# --- Solution ---#
#from sklearn.metrics import classification_report
#print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       233
#            1       0.98      1.00      0.99       179
#
#     accuracy                           0.99       412
#    macro avg       0.99      0.99      0.99       412
# weighted avg       0.99      0.99      0.99       412

# %%
minmaxScaler = preprocessing.MinMaxScaler()

# %%
notes_data['VarianceTransformed'] = minmaxScaler.fit_transform(x)

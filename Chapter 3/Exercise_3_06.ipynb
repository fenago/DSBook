# %% [markdown]
# ## Exercise 3_06 - Guided Exercise
# ### : A Logistic Regression Model for Predicting the Accuracy of Notes

# %% [markdown]
# ### Importing necessary modules

# %%
import pandas as pd
import numpy as np
from pandas import set_option

# %% [markdown]
# ### Loading Data from Bank Note Authentication Dataset

# %%
notes_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/datasets/main/BankNote_Authentication.csv')
#-------Type code here to display first five entries from daatset ------#


#------Solution------#
notes_data.head()

# %% [markdown]
# ### Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
#find the data types:

#Type your code:



# ---Solution--- #
#notes_data.dtypes

# %% [markdown]
# ###  Converting categorical variables to dummy variables

# %%
"""
Converting all the categorical variables to dummy variables
"""
Category = pd.get_dummies\
          (notes_data[['variance','skewness',\
                     'curtosis','entropy']])
Category.shape

# %% [markdown]
# ### Separating the numerical variables:

# %%
# All of the variables are numerical:
# Just type your code here to obtain them:



# --- Solytion ---#
#notes_Num = notes_data[['variance','skewness',\
#                     'curtosis','entropy']]

# Printing the shape:
notes_Num.shape

# %%
# Preparing the X variables
X = pd.concat([Category, notes_Num], axis=1)
print(X.shape)
# Preparing the Y variable
Y = notes_data['class']
print(Y.shape)
X.head()

# %%
#  Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split\
                                   (X, Y, test_size=0.3, \
                                    random_state=123)

# %% [markdown]
# ### Define the LogisticRegression function:

# %%
notes_Model = LogisticRegression()
notes_Model.fit(X_train, y_train)

# %% [markdown]
# ###  Model is created, use it for predicting on the test sets and then getting the accuracy level of the predictions:

# %%
pred = notes_Model.predict(X_test)
print('Accuracy of Logistic regression model' \
      'prediction on test set is: {:.2f}'\
      .format(notes_Model.score(X_test, y_test)))

# %% [markdown]
# ### Confusion Matrix for the Above Model:

# %%
# Confusion Matrix for the model
from sklearn.metrics import confusion_matrix

confusionMatrix = confusion_matrix(y_test, pred)
print(confusionMatrix)

# %% [markdown]
# ### Generating a classification report:

# %%
# For generating a classification report, type your code here:



# --- Solution ---#
#from sklearn.metrics import classification_report
#print(classification_report(y_test, pred))

# %% [markdown]
# ## **Exercise 3_05 - Guided Exercise**
# ### Finding the Correlation in Data to Generate a Correlation Plot Using  Notes Data

# %% [markdown]
# ### Importing necessary modules

# %%
import pandas as pd
import numpy as np

# import the set_option library from pandas:
from pandas import set_option

# %% [markdown]
# ### Loading Data from Bank Note Authentication Dataset

# %%
notes_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/datasets/main/BankNote_Authentication.csv')
#-------Type code here to display first five entries from daatset ------#


#------Solution------#
notes_data.head()

# %% [markdown]
# ### Creating a variable that would store numerical variables

# %%
notesNumeric = notes_data[['variance','skewness','curtosis','entropy',\
                        'class']]

# %% [markdown]
# ### Using the .corr() function to find the correlation matrix for the dataset

# %%
# Type your code here:




#--- Solution ---#
#set_option('display.width',180)
#set_option('precision',4)
#notes_Corr = notesNumeric.corr(method = 'pearson')

notesNumeric

# %% [markdown]
# ### Plotting the Data:

# %%
from matplotlib import pyplot
corrFig = pyplot.figure()
figAxis = corrFig.add_subplot(111)
corAx = figAxis.matshow(notes_Corr,vmin=-1,vmax=1)
corrFig.colorbar(corAx)
pyplot.show()

# %% [markdown]
# ## **Exercise 3_01 - Guided Exercise**
# ###  Loading and Exploring the Data from the Dataset - We ave used a Dataset of "Bank Note Authentication"

# %% [markdown]
# ### Importing  necessary modules

# %%
import pandas as pd

# %matplotlib inline
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg
import numpy as np
import patsy
from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split
plt.style.use('seaborn')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Loading Data:

# %%
notes_data = pd.read_csv\
('https://raw.githubusercontent.com/fenago/datasets/main/BankNote_Authentication.csv')
#-------Type code here to display first five entries from daatset ------#


#------Solution------#
#notes_data.head()

# %% [markdown]
# ###  Print the shape of the dataset

# %%
# The .shape function is used to find the overall shape of the dataset.
print(notes_data.shape)

# %% [markdown]
# ### find the summary of the numerical raw data as a table output using the .describe() function in pandas

# %%
#  ---- Write syntax here ---- #


#----Solution----#
#notes_data.describe()

# %% [markdown]
# ## **Solution_Activity 8.01**

# %%
#@title Import modules
import pandas as pd

# %%
#@title LOading data and extracting features
mushrooms = pd.read_csv('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%2008/agaricus-lepiota.data', header=None)
y_raw = mushrooms.iloc[:,0]
X_raw = mushrooms.iloc[:,1:]
y = (y_raw == 'p') * 1

# %% [markdown]
# ### The featureset X will need to have its columns transformed into a numpy array with a binary representation. This is known as one-hot encoding
# #Initialize the classifier.

# %% [markdown]
# ### Conduct both a grid and random search to find an optimal hyperparameterization for a random forest classifier

# %% [markdown]
# ### Plot the mean test score versus hyperparameterization for the top 10 models found using random search:

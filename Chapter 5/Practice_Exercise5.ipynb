# %% [markdown]
# ## Practice Exercise 5

# %%
#@title Importing modules
import pandas as pd
from sklearn.cluster import KMeans
import altair as alt
import numpy as np

# %% [markdown]
# ### link to dataset

# %%
file_url = 'https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%205/tax.csv'

# %% [markdown]
# ###   Load dataset with the extraction of columns: 'Average total business income' and 'Average total business expenses'

# %% [markdown]
# ### Assign the columns to a new variable

# %% [markdown]
# ### Fit a k-means model with n_init equal to 1 and a random init

# %% [markdown]
# ### Use the predict method from the sklearn package, predict the clustering assignment from the input variable, (X)

# %% [markdown]
# ### Plot the clusters using an interactive scatter plot.

# %% [markdown]
# ###  Use the encode and interactive methods from altair to specify the display of the scatter plot and its interactivity options

# %% [markdown]
# ### Repeat Steps 5 to 8 but with different k-means hyperparameters, n_init=10 and random init,

# %% [markdown]
# ###  Again, repeat Steps 5 to 8 but with different k-means hyperparameters – n_init=100 and random init

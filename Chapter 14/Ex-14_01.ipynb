# %% [markdown]
# ## **Exercise 14.01:**
# ### Loading and Cleaning the Dataset

# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd

# %% [markdown]
# ### Loading  Data

# %%
# Defining file name of the git hub repository

filename = 'https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%2014/hcvdata.csv'

# %%
# Loading the data using pandas

adData = pd.read_csv(filename,sep=",",header = None,error_bad_lines=False)
adData.head()

# %% [markdown]
# ### Printing the Shape of  the Dataset

# %%
# Printing the shape of the data
print(adData.shape)

# %% [markdown]
# ### Finding the summary of the numerical raw data using .describe() function

# %%
#Summarizing the statistics of the numerical raw data
adData.describe()

# %% [markdown]
# ### Seperating the dependent and independent variables from the dataset

# %%
# Seperating the dependent and independent variables
# Preparing the X variables
X = adData.loc[:,0:10]
print(X.shape)
# Preparing the Y variable
Y = adData[11]
print(Y.shape)

# %% [markdown]
# ### Printing first 15 examples of the independent variables

# %%
# Printing the head of the independent variables
X.head(15)

# %% [markdown]
# ### Printing the DataTypes of the Dataset

# %%
# Printing the data types
print(X.dtypes)

# %% [markdown]
# ### Replacing special characters with NaN values for first 3 columns

# %%
# Replacing special characters in first 3 columns which are of type object
for i in range(0,3):
  X[i] = X[i].str.replace("?", 'NaN').values.astype(float)
print(X.head(15))

# %% [markdown]
# ### Replacing special characters for Integer values

# %%
# Replacing special characters in the remaining columns which are of type integer
for i in range(3,11):
  X[i] = X[i].replace("?", 'NaN').values.astype(float)

# %% [markdown]
# ### Imputing Mean of each column for NaN values using .mean() function

# %%
import numpy as np

# Imputing the 'NaN'  with mean of the values
for i in range(0,10):
  X[i] = X[i].fillna(X[i].mean())
  
print(X.head(15))

# %% [markdown]
# ### Scaling the dataset using minimaxScaler() function.

# %%
# Scaling the data sets
# Import library function
from sklearn import preprocessing
# Creating the scaling function
minmaxScaler = preprocessing.MinMaxScaler()
# Transforming with the scaler function
X_tran = pd.DataFrame(minmaxScaler.fit_transform(X))
# Printing the output
X_tran.head()
